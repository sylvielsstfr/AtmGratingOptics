# %% [markdown]
# # Optical calculation for CTIO and Calypso
#
# - Sylvie Dagoret-Campagne
# - 11 janvier 2017
#
# - sage notebook : "sage -n jupyter"

# %% [markdown]
# ## CTIO 0.9 m

# %%
arcsecTorad=2*pi/360./60./60.  # rad per arcsec

# %%
n(arcsecTorad)
# Out:
# 4.84813681109536e-6

# %%
radToarcsec=1./arcsecTorad

# %%
f=12.6 # focale in meters

# %%
dx_pix=24 # microns per pixels

# %%
pix_angl=dx_pix*1e-6/f*radToarcsec  # arcsec per pixel

# %%
print n(pix_angl), 'arcsec per pixel'
# Out:
# 1.00000000000000 arcsec per pixel

# %%
angl_pix=dx_pix/dx_pix_angl

# %%
print n(angl_pix), 'arcsec per pixel'
# Out:
# 1.00000000000000 arcsec per pixel

# %%
def PlotOptics():
    p1=plot(0,(x,-10,10),figsize=(15,8),frame=True,gridlines=True,axes_labels=['x','y'])
    p2=plot
    p=p1
    return p

# %%
PlotOptics()
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
P1=point((0, 0), size=40)
p1=plot(sin(x),(x,-1,10),figsize=(15,8),frame=True,gridlines=True,axes_labels=['x','y'])
Ray1Ob=line( [(-1,1),(0,1)], color="red",thickness=1)
Ray2Ob=line( [(-1,-1),(0,-1)], color="red",thickness=1)
Ray1Im=line( [(0,1),(12.6,0)], color="red",thickness=1)
Ray2Im=line( [(0,-1),(12.6,0)], color="red",thickness=1)
P=Ray1Ob+Ray2Ob+Ray1Im+Ray2Im+p1+P1
show(P, figsize=15,aspect_ratio=1)
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
out1=solve(x^2 + 3*x + 2, x)

# %%
x, y = var('x, y')
out2=solve([x+y==6, x-y==4], x, y)

# %%
out1
# Out:
# [x == -2, x == -1]

# %%
out1[0].rhs()
# Out:
# -2

# %%
out2
# Out:
# [[x == 5, y == 1]]

# %%
out2[0][0].rhs()
# Out:
# 5
